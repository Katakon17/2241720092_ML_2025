# %% [markdown]
# # Praktikum 1
#
# ## Deskripsi
#
# Pada praktikum ini kita akan membuat model klasifikasi CNN sederhana pada kasus citra kucing dan anjing.
#
# ## Dataset
#
# Dataset merupakan data citra anjing dan kucing yang telah dibagi menjadi data training dan data testing. Dikarenakan data cukup besar, pastikan koneksi Anda sebelum mengunduh dataset.
#
# ➡️ [DOWNLOAD](https://drive.google.com/file/d/1vYrqBI1VmiXXJd5sgtKK2nuQvC8T1ryb/view?usp=drive_link) ⬅️

# %% [markdown]
# # Langkah 1 - Import Library

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # Langkah 2 - Pra Pengolahan Data
# Pada tahap ini kita akan sedikit melakukan manipulasi pada citra yang digunakan. Manipulasi yang dilakukan diantaranya adalah normalisasi nilai piksel, koreksi kemiringan (shear), pembesaran (zoom), dan horizontal flip.

# %% [markdown]
# # Langkah 2.1 - Pra Pengolahan Data Training

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# # Langkah 2.2 - Pra Pengolahan Data Testing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# # Langkah 3 - Pembuatan Model CNN

# %% [markdown]
# # Langkah 3.1 - Inisiasi Model CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# # Langkah 3.2 - Pembuatan Layer Konvolusi 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# c:\Users\broto\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Langkah 3.3 - Pembuatan Layer Pooling 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# # Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# # Langkah 3.5 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# # Langkah 3.6 - Fully Connected Layer 1 (Input)

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# # Langkah 3.7 - Fully Connected Layer 2 (Output)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# # Langkah 3.8 - Compile Model CNN
# Penggunaan loss function binary crossentropy dikarenakan kita hanya melakukan klasifikasi pada dua kelas, yaitu kucing dan anjing.

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# # Langkah 4 - Fit CNN

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 137s 543ms/step - accuracy: 0.5746 - loss: 0.6714 - val_accuracy: 0.6705 - val_loss: 0.6061
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 137s 543ms/step - accuracy: 0.5746 - loss: 0.6714 - val_accuracy: 0.6705 - val_loss: 0.6061
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - accuracy: 0.6777 - loss: 0.5961 - val_accuracy: 0.6940 - val_loss: 0.5954
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 38s 150ms/step - accuracy: 0.6777 - loss: 0.5961 - val_accuracy: 0.6940 - val_loss: 0.5954
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━
25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 140ms/step - accuracy: 0.8438 - loss: 0.3565 - val_accuracy: 0.7780 - val_loss: 0.4810
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 140ms/step - accuracy: 0.8438 - loss: 0.3565 - val_accuracy: 0.7780 - val_loss: 0.4810
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - accuracy: 0.8482 - loss: 0.3407 - val_accuracy: 0.7990 - val_loss: 0.4678
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - accuracy: 0.8482 - loss: 0.3407 - val_accuracy: 0.7990 - val_loss: 0.4678
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - accuracy: 0.8524 - loss: 0.3343 - val_accuracy: 0.7715 - val_loss: 0.5431
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - accuracy: 0.8524 - loss: 0.3343 - val_accuracy: 0.7715 - val_loss: 0.5431
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.8620 - loss: 0.3162 - val_accuracy: 0.7835 - val_loss: 0.5286
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.8620 - loss: 0.3162 - val_accuracy: 0.7835 - val_loss: 0.5286
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 170ms/step - accuracy: 0.8683 - loss: 0.3016 - val_accuracy: 0.7940 - val_loss: 0.4929
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 43s 170ms/step - accuracy: 0.8683 - loss: 0.3016 - val_accuracy: 0.7940 - val_loss: 0.4929
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 154ms/step - accuracy: 0.8806 - loss: 0.2871 - val_accuracy: 0.7995 - val_loss: 0.4977
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 154ms/step - accuracy: 0.8806 - loss: 0.2871 - val_accuracy: 0.7995 - val_loss: 0.4977
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.8811 - loss: 0.2821 - val_accuracy: 0.7895 - val_loss: 0.4921
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 149ms/step - accuracy: 0.8811 - loss: 0.2821 - val_accuracy: 0.7895 - val_loss: 0.4921
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - accuracy: 0.8895 - loss: 0.2657 - val_accuracy: 0.7880 - val_loss: 0.5044
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - accuracy: 0.8895 - loss: 0.2657 - val_accuracy: 0.7880 - val_loss: 0.5044
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 148ms/step - accuracy: 0.8971 - loss: 0.2437 - val_accuracy: 0.7895 - val_loss: 0.5744
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 37s 148ms/step - accuracy: 0.8971 - loss: 0.2437 - val_accuracy: 0.7895 - val_loss: 0.5744
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9019 - loss: 0.2403 - val_accuracy: 0.7860 - val_loss: 0.5397
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 39s 156ms/step - accuracy: 0.9019 - loss: 0.2403 - val_accuracy: 0.7860 - val_loss: 0.5397
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.9031 - loss: 0.2329 - val_accuracy: 0.8040 - val_loss: 0.5058
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.9031 - loss: 0.2329 - val_accuracy: 0.8040 - val_loss: 0.5058

# %% [markdown]
# # Langkah 5 - Prediksi dengan 1 Citra

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
